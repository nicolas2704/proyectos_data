# %% [markdown]
# # 💻 IA - Programación 2 - Trabajo Final 📊
#
# 💻 Ejercicio de Visualización de Datos con Plotly Express 📊
#
# En este ejercicio, deberás crear una función en Python llamada `plot_interactive_graphs`  que genere gráficos interactivos para analizar dos conjuntos de datos conocidos en Python: `iris` y `palmer_penguins`.
#
# La función debe permitir seleccionar el conjunto de datos y mostrar tres gráficos interactivos diferentes
#
# 📈 El trabajo esta realizado siguiendo estas pautas:
#
# 1️⃣ Solicitar el nombre del dataset a utilizar: La función debe preguntar al usuario cuál dataset desea visualizar. Las opciones son iris o palmer_penguins.
#
# 2️⃣ Cargar el dataset: Según la selección del usuario, carga el dataset correspondiente. Asegúrate de usar el módulo seaborn para cargar los datos 🐧.
#
# 3️⃣ Generar gráficos:
#
# 📊 Gráfico de Barras: Debe mostrar la longitud promedio del sépalo (para iris) o de la aleta (para palmer_penguins) según la especie.
#
# 🥧 Gráfico Circular: Representa la distribución de las especies en el dataset.
#
# 📉 Gráfico de Bigotes (Boxplot): Muestra la distribución de la anchura del sépalo (para iris) o la profundidad del pico (para palmer_penguins) según la especie.
#
# 4️⃣ Mostrar los gráficos: Cada gráfico debe ser interactivo y mostrarse en pantalla 📱.
#
# ⚠️ Importante:
#
# Utiliza plotly.express para crear gráficos visualmente atractivos e interactivos.
#
# Asegúrate de que los títulos de los gráficos cambien según el dataset seleccionado para que sean más descriptivos 🎯.
#
# Si el usuario ingresa un nombre de dataset no válido, muestra un mensaje de error apropiado ⚠️.

# %% [markdown]
# # `**dataset Iris **`
# El conjunto de datos de Iris contiene cuatro características (longitud y anchura de sépalos y pétalos) de 50 muestras de tres especies de flores Iris (Iris setosa, Iris virginica e Iris versicolor).

# %% [markdown]
# ![iris_flowers.png](data:image/png;base64,...)

# %% [markdown]
# # `**dataset Penguins **`
# El dataset palmer penguins es un conjunto de datos sobre pingüinos de tres especies diferentes que anidan en una colonia de Archipiélago Palmer, en la Antártida.
# Contiene información sobre las medidas corporales de los pingüinos, incluyendo la longitud y profundidad del pico, la longitud de la aleta y la masa corporal, así como información sobre el sexo y la edad de los pingüinos.
#
# Hay tres especies de pingüinos en el conjunto de datos: Adelie, Gentoo, y Chinstrap.

# %% [markdown]
# ![lter_penguins.png](data:image/png;base64,...)

# %%
import plotly.express as px  # Importa la librería Plotly Express para crear gráficos interactivos.
import seaborn as sns        # Importa la librería Seaborn para cargar conjuntos de datos utilizados.
import pandas as pd          # Importa Pandas para la manipulación y análisis de datos.

# Se define una función plot_interactive_graphs que permite generar graficos interactivos
def plot_interactive_graphs():
    # Solicitamos al usuario que elija uno de los conjuntos de datos disponibles, "iris" o "palmer_penguins" >> "palmer" para su análisis
    dataset_name = input("¿Qué conjunto de datos desea utilizar? ( iris / penguins ): ").strip().lower()

    # Carga el conjunto de datos en función de la selección del usuario
    if dataset_name == 'iris':
        data = sns.load_dataset('iris')  # Carga el conjunto de datos 'iris' utilizando Seaborn.
        print(" ** Estructura del conjunto de datos seleccionado ** ")
        print(data.columns)
        data=data.rename(columns={"sepal_length":"largo_sepalo","sepal_width":"ancho_sepalo","petal_length":"largo_petalo",
                                  "petal_width":"ancho_petalo","species":"especies"})
        print(data.head(5))  # Muestra las primeras filas del conjunto de datos para una inspección inicial.

        print(" ** Distribución x tipo de flores iris ** ")
        print(data['especies'].value_counts()) # Cantidad de datos x  especies

       # Agrupa los datos por la columna 'species' y calcula el promedio de 'sepal_length' para cada tipo de iris.
        data_bar = data.groupby('especies', as_index=False)['largo_sepalo'].mean()


        bar_title = 'Gráfico de Barras: Longitud promedio del sépalo (cm)'  # Define el título para el gráfico de barras.
        box_title = 'Gráfico de Bigotes: Anchura del sépalo (cm)'  # Define el título para el gráfico de bigotes.
        pie_title = 'Gráfico Circular: Distribución de Tipo de Flores'  # Define el título para el gráfico Circular.

        x_column = 'especies'  # Define la columna que se usará en el eje x, en este caso, 'species' (especies).
        y_column_bar = 'largo_sepalo'  # Define la columna que se usará en el eje y del gráfico de barras, 'sepal_length' (largo del sépalo).
        y_column_box = 'ancho_sepalo'  # Define la columna que se usará en el eje y del gráfico de barras, 'sepal_width' (anchura del sépalo).

        color_column = 'especies'  # Define la columna que se usará para colorear los datos en los gráficos, en este caso, 'species'.

    elif dataset_name == 'penguins':
        data = sns.load_dataset('penguins')  # Carga el conjunto de datos 'penguins' utilizando Seaborn.

        print(" ** Estructura del conjunto de datos seleccionado ** ")
        data=data.rename(columns={"species":"especies","island":"islas","bill_length_mm":"largo_pico_mm","bill_depth_mm":"profundidad_pico_mm",
                                  "flipper_length_mm":"largo_aletas_mm","body_mass_g":"masa_corporal_gr","sex":"sexo"})
        print(data.head(5))  # Muestra las primeras filas del conjunto de datos para una inspección inicial.

        print(" ** Distribución x tipo de pinguinos ** ")
        print(data['especies'].value_counts()) # Cantidad de datos x especies

        # Agrupa los datos por la columna 'species' y calcula el promedio de 'flipper_length_mm' para cada tipo de corte.
        data_bar = data.groupby('especies', as_index=False)['largo_aletas_mm'].mean()

        bar_title = 'Gráfico de Barras: Longitud promedio de las aletas (mm)'  # Título para el gráfico de barras.
        box_title = 'Gráfico de Bigotes: Profundidad del pico (mm)'  # Título para el gráfico de bigotes.
        pie_title = 'Gráfico Circular: Distribución de Especies de Pinguinos'  # Define el título para el gráfico Circular.

        x_column = 'especies'  # Define la columna que se usará en el eje x, en este caso, 'species' (tipo de pinguinos).
        y_column_bar = 'largo_aletas_mm'  # Define la columna para el eje y del gráfico de barras, 'flipper_lenght_mm' (largo de las aletas).
        y_column_box = 'profundidad_pico_mm'  # Define la columna para el eje y del gráfico de barras, 'bill_depth_mm' (profundidad del pico).
        color_column = 'especies'  # Define la columna para colorear los datos en los gráficos, en este caso, 'species'.

    else:
         # Muestra un mensaje de error si el usuario no selecciona un conjunto de datos válido y finaliza la función.
        print("Error: el nombre del dataset debe ser 'iris' o 'penguins'.")
        return

    # Gráfico de barras (bar): muestra el promedio del largo de la especie
    fig_bar = px.bar(data_bar, x=x_column, y=y_column_bar, title=bar_title, color=color_column,
                      color_discrete_map={'Especie1': '#C65AD6',
                                          'Especie2': '#50B5AE',
                                          'Especie3': '#E07924'})
    fig_bar.update_layout(template='plotly_dark')  # Aplicar el tema oscuro

    # Gráfico circular (pie): muestra la distribución de la columna seleccionada.
    fig_pie = px.pie(data, names=x_column, title=pie_title,
                     color=x_column,
                     color_discrete_map={'Especie1': '#C65AD6',
                                          'Especie2': '#50B5AE',
                                          'Especie3': '#E07924'})
    fig_pie.update_layout(template='plotly_dark')  # Aplicar el tema oscuro

    # Gráfico de bigotes (boxplot): muestra la distribución de la columna
    fig_box = px.box(data, x=x_column, y=y_column_box, title=box_title,
                     color=x_column,
                     color_discrete_map={'Especie1': '#C65AD6',
                                          'Especie2': '#50B5AE',
                                          'Especie3': '#E07924'})
    fig_box.update_layout(template='plotly_dark')  # Aplicar el tema oscuro

    fig_bar.show()  # Muestra el gráfico de barras.
    fig_pie.show()  # Muestra el gráfico circular.
    fig_box.show()  # Muestra el gráfico de bigotes.

# Ejecutar la función para solicitar el dataset y generar los gráficos
plot_interactive_graphs()
# Out:
# ¿Qué conjunto de datos desea utilizar? ( iris / penguins ): penguins
#  ** Estructura del conjunto de datos seleccionado **
#   especies      islas  largo_pico_mm  profundidad_pico_mm  largo_aletas_mm  \
# 0   Adelie  Torgersen           39.1                 18.7            181.0
# 1   Adelie  Torgersen           39.5                 17.4            186.0
# 2   Adelie  Torgersen           40.3                 18.0            195.0
# 3   Adelie  Torgersen            NaN                  NaN              NaN
# 4   Adelie  Torgersen           36.7                 19.3            193.0
#
#    masa_corporal_gr    sexo
# 0            3750.0    Male
# 1            3800.0  Female
# 2            3250.0  Female
# 3               NaN     NaN
# 4            3450.0  Female
#  ** Distribución x tipo de pinguinos **
# especies
# Adelie       152
# Gentoo       124
# Chinstrap     68
# Name: count, dtype: int64
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
# ...
